# %% [markdown]
# ### We would like to use a neural network, now
# - The data should follow a comprehensive workflow to ensure data is well-prepared and the model is appropriately designed and evaluated
#
# #### Steps:
# 1. Import Data
# 2. Train-Val-Test
# 3. Preprocess Data
#     - Handle Missing Values
#     - Normalize/Scale Data
#     - Encode Categorical Data
#     - Text Processing
#     - Handle Outliers
# 4. Create Pipeline for Numerical and Categorical Data
# 5. Build the nn
# 6. Compile and Train Model
# 7. Evaluate Model
# 8. Tune Hyperparameters
# 9. Model Interpretation and Feature Importance
# 10. Save/Load Model
# 11. Deploy Model

# %% [markdown]
# ### 1. Import the data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fire_csv = '../../datasets/Fire-Incidents.csv'

fire_df = pd.read_csv(fire_csv)
fire_df.head()
# Out:
#                                       Area_of_Origin  \
# 0                                   Porch or Balcony
# 1                            Cooking Area or Kitchen
# 2     Living Area (e.g. living, TV, recreation, etc)
# 3                        Undetermined  (formerly 98)
# 4  Sleeping Area or Bedroom (inc. patients room, ...
#
#                    Business_Impact  Civilian_Casualties  \
# 0         No business interruption                    0
# 1                     Undetermined                    0
# 2  Not applicable (not a business)                    1
# 3        May not resume operations                    0
# 4  Not applicable (not a business)                    8
#
#    Count_of_Persons_Rescued  Estimated_Dollar_Loss  \
# 0                        86                   3000
# 1                        28                  50000
# 2                        16                1000000
# 3                        12                1000000
# 4                        11                 125000
#
#    Estimated_Number_Of_Persons_Displaced Ext_agent_app_or_defer_time  \
# 0                                      0         2018-08-24T17:06:26
# 1                                     28         2018-11-24T07:19:00
# 2                                    130         2017-02-09T18:02:13
# 3                                     14         2012-10-30T00:52:04
# 4                                      2         2018-07-08T04:35:00
#
#                              Extent_Of_Fire  \
# 0              Confined to object of origin
# 1   Confined to part of room/area of origin
# 2  Spread beyond room of origin, same floor
# 3                          Entire Structure
# 4  Spread beyond room of origin, same floor
#
#               Fire_Alarm_System_Impact_on_Evacuation  \
# 0  Not applicable: Occupant(s) first alerted by o...
# 1  Not applicable: Occupant(s) first alerted by o...
# 2  Some persons (at risk) evacuated as a result o...
# 3                                       Undetermined
# 4  Some persons (at risk) evacuated as a result o...
#
#                 Fire_Alarm_System_Operation  ...  Longitude  \
# 0         Fire alarm system did not operate  ... -79.412479
# 1                Fire alarm system operated  ... -79.530419
# 2                Fire alarm system operated  ... -79.373460
# 3  Fire alarm system operation undetermined  ... -79.393700
# 4                Fire alarm system operated  ... -79.511539
#
#        Material_First_Ignited           Method_Of_Fire_Control  \
# 0  Undetermined (formerly 98)  Extinguished by fire department
# 1                     Plastic         Extinguished by occupant
# 2  Undetermined (formerly 98)  Extinguished by fire department
# 3  Undetermined (formerly 98)  Extinguished by fire department
# 4                     Bedding  Extinguished by fire department
#
#         Possible_Cause                         Property_Use  \
# 0         Undetermined  Multi-Unit Dwelling - Over 12 Units
# 1  Under Investigation                            Infirmary
# 2         Undetermined  Multi-Unit Dwelling - Over 12 Units
# 3         Undetermined     Clothing Store, Accessories, fur
# 4      Suspected Arson  Multi-Unit Dwelling - Over 12 Units
#
#             Smoke_Alarm_at_Fire_Origin_Alarm_Failure  \
# 0  Not applicable: Alarm operated OR presence/ope...
# 1  Not applicable: Alarm operated OR presence/ope...
# 2  Not applicable: Alarm operated OR presence/ope...
# 3  Not applicable: Alarm operated OR presence/ope...
# 4  Not applicable: Alarm operated OR presence/ope...
#
#    Smoke_Alarm_at_Fire_Origin_Alarm_Type  \
# 0                 Hardwired (standalone)
# 1                         Interconnected
# 2                 Hardwired (standalone)
# 3                      Type undetermined
# 4                         Interconnected
#
#                            Status_of_Fire_On_Arrival       TFS_Alarm_Time  \
# 0  Fire with smoke showing only - including vehic...  2018-08-24T16:49:36
# 1                 Fire extinguished prior to arrival  2018-11-24T07:09:12
# 2  Flames showing from small area (one storey or ...  2017-02-09T17:45:07
# 3  Flames showing from large area (more than one ...  2012-10-30T00:42:01
# 4                  Fire with no evidence from street  2018-07-08T04:08:50
#
#       TFS_Arrival_Time
# 0  2018-08-24T16:54:09
# 1  2018-11-24T07:14:23
# 2  2017-02-09T17:48:49
# 3  2012-10-30T00:44:58
# 4  2018-07-08T04:13:54
#
# [5 rows x 27 columns]

# %%
fire_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11214 entries, 0 to 11213
# Data columns (total 27 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Area_of_Origin                            11214 non-null  object
#  1   Business_Impact                           11214 non-null  object
#  2   Civilian_Casualties                       11214 non-null  int64
#  3   Count_of_Persons_Rescued                  11214 non-null  int64
#  4   Estimated_Dollar_Loss                     11214 non-null  int64
#  5   Estimated_Number_Of_Persons_Displaced     11214 non-null  int64
#  6   Ext_agent_app_or_defer_time               11214 non-null  object
#  7   Extent_Of_Fire                            11214 non-null  object
#  8   Fire_Alarm_System_Impact_on_Evacuation    11214 non-null  object
#  9   Fire_Alarm_System_Operation               11214 non-null  object
#  10  Fire_Alarm_System_Presence                11214 non-null  object
#  11  Fire_Under_Control_Time                   11214 non-null  object
#  12  Ignition_Source                           11214 non-null  object
#  13  Incident_Station_Area                     11214 non-null  int64
#  14  Incident_Ward                             11181 non-null  float64
#  15  Last_TFS_Unit_Clear_Time                  11214 non-null  object
#  16  Latitude                                  11214 non-null  float64
#  17  Longitude                                 11214 non-null  float64
#  18  Material_First_Ignited                    11214 non-null  object
#  19  Method_Of_Fire_Control                    11214 non-null  object
#  20  Possible_Cause                            11214 non-null  object
#  21  Property_Use                              11214 non-null  object
#  22  Smoke_Alarm_at_Fire_Origin_Alarm_Failure  11214 non-null  object
#  23  Smoke_Alarm_at_Fire_Origin_Alarm_Type     11214 non-null  object
#  24  Status_of_Fire_On_Arrival                 11214 non-null  object
#  25  TFS_Alarm_Time                            11214 non-null  object
#  26  TFS_Arrival_Time                          11214 non-null  object
# dtypes: float64(3), int64(5), object(19)
# memory usage: 2.3+ MB

# %%
# Change the column names so they are uniform

fire_df.columns = ['origin', 'busi_impact', 'num_casualties', 'num_rescued', 'est_loss', 
                   'est_displaced', 'ext_agent_app_or_defer_time', 'extent', 'fire_alarm_impact_on_evac',
                   'fire_alarm_sys_op', 'fire_alarm_presence', 'fire_under_control_time', 'ignition_source',
                   'incident_station_area', 'incident_ward', 'last_tfs_unit_clear_time', 'latitude',
                   'longitude', 'material_first_ignited', 'method_of_fire_control', 'possible_cause',
                   'property_use', 'smoke_alarm_at_fire_origin_alarm_failure',
                   'smoke_alarm_at_fire_origin_alarm_type', 'status_of_fire_on_arrival',
                   'alarm_time', 'arrival_time']
fire_df['alarm_time'] = pd.to_datetime(fire.alarm_time)
fire_df['arrival_time'] = pd.to_datetime(fire.arrival_time)

# %% [markdown]
# ### 2. Split the data

# %%
from sklearn.model_selection import train_test_split as tts

train_set, test_set = tts(fire_df, test_size=0.2, random_state=42)

# %%
train_set
# Out:
#                                                  origin  \
# 4743  Trash, Rubbish Storage (inc garbage chute room...
# 3790                      Trash, rubbish area (outside)
# 9395                             Concealed Ceiling Area
# 7440  HVAC Equipment Room (furnace room, water heate...
# 4823                         Locker (apartment storage)
# ...                                                 ...
# 5734  Trash, Rubbish Storage (inc garbage chute room...
# 5191  Trash, Rubbish Storage (inc garbage chute room...
# 5390                      Trash, rubbish area (outside)
# 860                             Cooking Area or Kitchen
# 7270                                   Porch or Balcony
#
#                               busi_impact  num_casualties  num_rescued  \
# 4743             No business interruption               0            0
# 3790             No business interruption               0            0
# 9395  May resume operations within a week               0            0
# 7440             No business interruption               0            0
# 4823             No business interruption               0            0
# ...                                   ...             ...          ...
# 5734             No business interruption               0            0
# 5191             No business interruption               0            0
# 5390             No business interruption               0            0
# 860       Not applicable (not a business)               0            0
# 7270      Not applicable (not a business)               0            0
#
#       est_loss  est_displaced ext_agent_app_or_defer_time  \
# 4743     10000              0         2014-03-27T08:15:00
# 3790     40000              0         2014-08-09T16:31:00
# 9395     10000              0         2014-02-27T01:51:00
# 7440      2000              0         2017-11-07T20:42:15
# 4823       200              0         2014-04-03T17:21:00
# ...        ...            ...                         ...
# 5734         0              0         2012-12-03T11:48:30
# 5191       500              0         2015-11-17T23:27:05
# 5390      3000              0         2017-03-11T14:26:59
# 860      10000              4         2018-12-14T09:10:00
# 7270       300              0         2016-07-03T16:56:15
#
#                                        extent  \
# 4743             Confined to object of origin
# 3790  Confined to part of room/area of origin
# 9395  Confined to part of room/area of origin
# 7440             Confined to object of origin
# 4823  Confined to part of room/area of origin
# ...                                       ...
# 5734             Confined to object of origin
# 5191             Confined to object of origin
# 5390      Confined to roof/exterior structure
# 860   Confined to part of room/area of origin
# 7270             Confined to object of origin
#
#                               fire_alarm_impact_on_evac  \
# 4743  Not applicable: Occupant(s) first alerted by o...
# 3790  Not applicable: No fire alarm system, no perso...
# 9395                                       Undetermined
# 7440  No one (at risk) evacuated as a result of hear...
# 4823  Some persons (at risk) evacuated as a result o...
# ...                                                 ...
# 5734  All persons (at risk of injury) evacuated as a...
# 5191  Not applicable: Occupant(s) first alerted by o...
# 5390                                       Undetermined
# 860   All persons (at risk of injury) evacuated as a...
# 7270  Not applicable: No fire alarm system, no perso...
#
#                              fire_alarm_sys_op  ...  longitude  \
# 4743                Not applicable (no system)  ... -79.352480
# 3790                Not applicable (no system)  ... -79.472250
# 9395  Fire alarm system operation undetermined  ... -79.370140
# 7440                Fire alarm system operated  ... -79.237790
# 4823                Fire alarm system operated  ... -79.331240
# ...                                        ...  ...        ...
# 5734                Fire alarm system operated  ... -79.526610
# 5191  Fire alarm system operation undetermined  ... -79.172160
# 5390  Fire alarm system operation undetermined  ... -79.398350
# 860                 Fire alarm system operated  ... -79.516894
# 7270  Fire alarm system operation undetermined  ... -79.327150
#
#                 material_first_ignited            method_of_fire_control  \
# 4743        Undetermined (formerly 98)   Extinguished by fire department
# 3790             Rubbish, Trash, Waste   Extinguished by fire department
# 9395                        Insulation   Extinguished by fire department
# 7440        Undetermined (formerly 98)   Extinguished by fire department
# 4823  Multiple diverse objects ignited  Extinguished by automatic system
# ...                                ...                               ...
# 5734             Rubbish, Trash, Waste         Action taken unclassified
# 5191             Rubbish, Trash, Waste   Extinguished by fire department
# 5390                           Plastic   Extinguished by fire department
# 860   Multiple diverse objects ignited         Action taken unclassified
# 7270                           Propane   Extinguished by fire department
#
#                                  possible_cause  \
# 4743                         Mechanical Failure
# 3790                       Improperly Discarded
# 9395   Used or Placed too close to combustibles
# 7440                         Mechanical Failure
# 4823  Other unintentional cause, not classified
# ...                                         ...
# 5734  Other unintentional cause, not classified
# 5191  Other unintentional cause, not classified
# 5390                       Improperly Discarded
# 860                          Electrical Failure
# 7270  Other unintentional cause, not classified
#
#                                            property_use  \
# 4743                             Waste Transfer Station
# 3790                                    Detached Garage
# 9395                                               Bank
# 7440                Multi-Unit Dwelling - Over 12 Units
# 4823                Multi-Unit Dwelling - Over 12 Units
# ...                                                 ...
# 5734                 Multi-Unit Dwelling - 2 to 6 Units
# 5191  Attached Dwelling (eg. rowhouse, townhouse, etc.)
# 5390                    Attached Dwelling with Business
# 860                 Multi-Unit Dwelling - Over 12 Units
# 7270                                  Detached Dwelling
#
#                smoke_alarm_at_fire_origin_alarm_failure  \
# 4743                Reason for inoperation undetermined
# 3790  Not applicable: Alarm operated OR presence/ope...
# 9395                                       Other reason
# 7440  Not applicable: Alarm operated OR presence/ope...
# 4823  Not applicable: Alarm operated OR presence/ope...
# ...                                                 ...
# 5734  Not applicable: Alarm operated OR presence/ope...
# 5191                                       Other reason
# 5390  Not applicable: Alarm operated OR presence/ope...
# 860   Not applicable: Alarm operated OR presence/ope...
# 7270  Not applicable: Alarm operated OR presence/ope...
#
#                   smoke_alarm_at_fire_origin_alarm_type  \
# 4743  Not applicable - no smoke alarm or presence un...
# 3790  Not applicable - no smoke alarm or presence un...
# 9395                                  Type undetermined
# 7440                                  Type undetermined
# 4823                                     Interconnected
# ...                                                 ...
# 5734                             Hardwired (standalone)
# 5191  Not applicable - no smoke alarm or presence un...
# 5390  Not applicable - no smoke alarm or presence un...
# 860                              Hardwired (standalone)
# 7270  Not applicable - no smoke alarm or presence un...
#
#                               status_of_fire_on_arrival          alarm_time  \
# 4743  Fire with smoke showing only - including vehic... 2014-03-27 08:02:56
# 3790  Flames showing from small area (one storey or ... 2014-08-09 16:22:10
# 9395  Fire with smoke showing only - including vehic... 2014-02-27 01:35:00
# 7440                  Fire with no evidence from street 2017-11-07 20:27:58
# 4823                 Fire extinguished prior to arrival 2014-04-03 17:05:03
# ...                                                 ...                 ...
# 5734                 Fire extinguished prior to arrival 2012-12-03 11:43:26
# 5191  Flames showing from small area (one storey or ... 2015-11-17 23:20:37
# 5390  Fire with smoke showing only - including vehic... 2017-03-11 14:20:32
# 860                  Fire extinguished prior to arrival 2018-12-14 09:02:19
# 7270                  Fire with no evidence from street 2016-07-03 16:44:40
#
#             arrival_time
# 4743 2014-03-27 08:09:11
# 3790 2014-08-09 16:29:07
# 9395 2014-02-27 01:41:56
# 7440 2017-11-07 20:32:52
# 4823 2014-04-03 17:11:34
# ...                  ...
# 5734 2012-12-03 11:48:29
# 5191 2015-11-17 23:25:32
# 5390 2017-03-11 14:25:09
# 860  2018-12-14 09:04:35
# 7270 2016-07-03 16:50:04
#
# [8971 rows x 27 columns]

# %%
test_set
# Out:
#                                                  origin  \
# 3703  Washroom or Bathroom (toilet,restroom/locker r...
# 9792                            Cooking Area or Kitchen
# 9821                           Multiple Areas of Origin
# 303                             Cooking Area or Kitchen
# 4862                            Cooking Area or Kitchen
# ...                                                 ...
# 7298                      Trash, rubbish area (outside)
# 6010       Ducting - Exhaust (inc cooking, fumes, etc.)
# 6431  Washroom or Bathroom (toilet,restroom/locker r...
# 2629                                   Porch or Balcony
# 8913  Product Storage (inc products or materials awa...
#
#                           busi_impact  num_casualties  num_rescued  est_loss  \
# 3703  Not applicable (not a business)               0            0         0
# 9792         No business interruption               0            0    400000
# 9821        May not resume operations               0            0    500000
# 303   Not applicable (not a business)               0            1     75000
# 4862         No business interruption               0            0     10000
# ...                               ...             ...          ...       ...
# 7298         No business interruption               0            0       500
# 6010                     Undetermined               0            0      3000
# 6431         No business interruption               0            0      5000
# 2629  Not applicable (not a business)               0            0      1500
# 8913         No business interruption               0            0       500
#
#       est_displaced ext_agent_app_or_defer_time  \
# 3703              0         2011-10-26T07:13:00
# 9792              0         2016-01-26T15:54:56
# 9821              0         2012-02-01T01:50:00
# 303               2         2012-01-11T11:20:00
# 4862              2         2013-04-21T16:09:29
# ...             ...                         ...
# 7298              0         2016-11-15T00:41:26
# 6010             10         2016-09-15T08:04:00
# 6431             10         2015-06-12T03:55:00
# 2629              0         2017-04-28T16:24:30
# 8913              0         2011-09-30T00:35:00
#
#                                             extent  \
# 3703                  Confined to object of origin
# 9792  Spread to other floors, confined to building
# 9821                              Entire Structure
# 303                Spread to entire room of origin
# 4862       Confined to part of room/area of origin
# ...                                            ...
# 7298       Confined to part of room/area of origin
# 6010                  Confined to object of origin
# 6431       Confined to part of room/area of origin
# 2629       Confined to part of room/area of origin
# 8913                  Confined to object of origin
#
#                               fire_alarm_impact_on_evac  \
# 3703  Not applicable: No fire alarm system, no perso...
# 9792                                       Undetermined
# 9821                                       Undetermined
# 303   Not applicable: No fire alarm system, no perso...
# 4862                                       Undetermined
# ...                                                 ...
# 7298                                       Undetermined
# 6010  Not applicable: Occupant(s) first alerted by o...
# 6431  All persons (at risk of injury) evacuated as a...
# 2629  Not applicable: No fire alarm system, no perso...
# 8913  Not applicable: No fire alarm system, no perso...
#
#                              fire_alarm_sys_op  ... longitude  \
# 3703                Not applicable (no system)  ... -79.55728
# 9792  Fire alarm system operation undetermined  ... -79.47693
# 9821  Fire alarm system operation undetermined  ... -79.57588
# 303                 Not applicable (no system)  ... -79.44345
# 4862                Fire alarm system operated  ... -79.37150
# ...                                        ...  ...       ...
# 7298  Fire alarm system operation undetermined  ... -79.39209
# 6010                Not applicable (no system)  ... -79.27104
# 6431                Fire alarm system operated  ... -79.30174
# 2629                Fire alarm system operated  ... -79.36330
# 8913         Fire alarm system did not operate  ... -79.47278
#
#                          material_first_ignited  \
# 3703  Fabric - Natural (eg. cotton, wool, etc.)
# 9792                 Undetermined (formerly 98)
# 9821                 Undetermined (formerly 98)
# 303                                   Cabinetry
# 4862               Books, Magazines, Newspapers
# ...                                         ...
# 7298                      Rubbish, Trash, Waste
# 6010                                      Other
# 6431                          Structural Member
# 2629           Multiple diverse objects ignited
# 8913               Electrical Wiring Insulation
#
#                method_of_fire_control  \
# 3703         Extinguished by occupant
# 9792  Extinguished by fire department
# 9821  Extinguished by fire department
# 303   Extinguished by fire department
# 4862  Extinguished by fire department
# ...                               ...
# 7298  Extinguished by fire department
# 6010         Extinguished by occupant
# 6431           Fire self extinguished
# 2629  Extinguished by fire department
# 8913         Extinguished by occupant
#
#                                          possible_cause  \
# 3703  Design/Construction/Installation/Maintenance D...
# 9792          Other unintentional cause, not classified
# 9821                                       Undetermined
# 303           Other unintentional cause, not classified
# 4862                                         Unattended
# ...                                                 ...
# 7298                               Improperly Discarded
# 6010  Design/Construction/Installation/Maintenance D...
# 6431  Design/Construction/Installation/Maintenance D...
# 2629                               Improperly Discarded
# 8913  Design/Construction/Installation/Maintenance D...
#
#                                            property_use  \
# 3703                             Semi-Detached Dwelling
# 9792                                  Detached Dwelling
# 9821                        Motor Vehicle Repair Garage
# 303                                   Detached Dwelling
# 4862                Multi-Unit Dwelling - Over 12 Units
# ...                                                 ...
# 7298                            School - Pre-Elementary
# 6010  Mfg: Secondary Processing (eg finished goods, ...
# 6431                                  Detached Dwelling
# 2629                Multi-Unit Dwelling - Over 12 Units
# 8913                    Mfg: Meat/Poultry/Fish Products
#
#                smoke_alarm_at_fire_origin_alarm_failure  \
# 3703       Remote from fire – smoke did not reach alarm
# 9792  Not applicable: Alarm operated OR presence/ope...
# 9821  Not applicable: Alarm operated OR presence/ope...
# 303                 Reason for inoperation undetermined
# 4862  Not applicable: Alarm operated OR presence/ope...
# ...                                                 ...
# 7298  Not applicable: Alarm operated OR presence/ope...
# 6010  Not applicable: Alarm operated OR presence/ope...
# 6431  Not applicable: Alarm operated OR presence/ope...
# 2629  Not applicable: Alarm operated OR presence/ope...
# 8913       Remote from fire – smoke did not reach alarm
#
#                   smoke_alarm_at_fire_origin_alarm_type  \
# 3703                                   Battery operated
# 9792                                  Type undetermined
# 9821  Not applicable - no smoke alarm or presence un...
# 303                                   Type undetermined
# 4862                                     Interconnected
# ...                                                 ...
# 7298  Not applicable - no smoke alarm or presence un...
# 6010  Not applicable - no smoke alarm or presence un...
# 6431                                   Battery operated
# 2629                                  Type undetermined
# 8913                                     Interconnected
#
#                               status_of_fire_on_arrival alarm_time  \
# 3703                 Fire extinguished prior to arrival        NaT
# 9792  Fire with smoke showing only - including vehic...        NaT
# 9821  Fully involved (total structure, vehicle, spre...        NaT
# 303   Fire with smoke showing only - including vehic...        NaT
# 4862  Fire with smoke showing only - including vehic...        NaT
# ...                                                 ...        ...
# 7298  Fire with smoke showing only - including vehic...        NaT
# 6010                 Fire extinguished prior to arrival        NaT
# 6431  Fire with smoke showing only - including vehic...        NaT
# 2629  Flames showing from small area (one storey or ...        NaT
# 8913                 Fire extinguished prior to arrival        NaT
#
#      arrival_time
# 3703          NaT
# 9792          NaT
# 9821          NaT
# 303           NaT
# 4862          NaT
# ...           ...
# 7298          NaT
# 6010          NaT
# 6431          NaT
# 2629          NaT
# 8913          NaT
#
# [2243 rows x 27 columns]

# %% [markdown]
# ### 3. Preprocess the data

# %%
fire = train_set.copy()

# %%
# Add response_time column

fire['response_time'] = (fire.arrival_time - fire.alarm_time).dt.total_seconds()
fire.head()
# Out:
#                                                  origin  \
# 4743  Trash, Rubbish Storage (inc garbage chute room...
# 3790                      Trash, rubbish area (outside)
# 9395                             Concealed Ceiling Area
# 7440  HVAC Equipment Room (furnace room, water heate...
# 4823                         Locker (apartment storage)
#
#                               busi_impact  num_casualties  num_rescued  \
# 4743             No business interruption               0            0
# 3790             No business interruption               0            0
# 9395  May resume operations within a week               0            0
# 7440             No business interruption               0            0
# 4823             No business interruption               0            0
#
#       est_loss  est_displaced ext_agent_app_or_defer_time  \
# 4743     10000              0         2014-03-27T08:15:00
# 3790     40000              0         2014-08-09T16:31:00
# 9395     10000              0         2014-02-27T01:51:00
# 7440      2000              0         2017-11-07T20:42:15
# 4823       200              0         2014-04-03T17:21:00
#
#                                        extent  \
# 4743             Confined to object of origin
# 3790  Confined to part of room/area of origin
# 9395  Confined to part of room/area of origin
# 7440             Confined to object of origin
# 4823  Confined to part of room/area of origin
#
#                               fire_alarm_impact_on_evac  \
# 4743  Not applicable: Occupant(s) first alerted by o...
# 3790  Not applicable: No fire alarm system, no perso...
# 9395                                       Undetermined
# 7440  No one (at risk) evacuated as a result of hear...
# 4823  Some persons (at risk) evacuated as a result o...
#
#                              fire_alarm_sys_op  ...  \
# 4743                Not applicable (no system)  ...
# 3790                Not applicable (no system)  ...
# 9395  Fire alarm system operation undetermined  ...
# 7440                Fire alarm system operated  ...
# 4823                Fire alarm system operated  ...
#
#                 material_first_ignited            method_of_fire_control  \
# 4743        Undetermined (formerly 98)   Extinguished by fire department
# 3790             Rubbish, Trash, Waste   Extinguished by fire department
# 9395                        Insulation   Extinguished by fire department
# 7440        Undetermined (formerly 98)   Extinguished by fire department
# 4823  Multiple diverse objects ignited  Extinguished by automatic system
#
#                                  possible_cause  \
# 4743                         Mechanical Failure
# 3790                       Improperly Discarded
# 9395   Used or Placed too close to combustibles
# 7440                         Mechanical Failure
# 4823  Other unintentional cause, not classified
#
#                              property_use  \
# 4743               Waste Transfer Station
# 3790                      Detached Garage
# 9395                                 Bank
# 7440  Multi-Unit Dwelling - Over 12 Units
# 4823  Multi-Unit Dwelling - Over 12 Units
#
#                smoke_alarm_at_fire_origin_alarm_failure  \
# 4743                Reason for inoperation undetermined
# 3790  Not applicable: Alarm operated OR presence/ope...
# 9395                                       Other reason
# 7440  Not applicable: Alarm operated OR presence/ope...
# 4823  Not applicable: Alarm operated OR presence/ope...
#
#                   smoke_alarm_at_fire_origin_alarm_type  \
# 4743  Not applicable - no smoke alarm or presence un...
# 3790  Not applicable - no smoke alarm or presence un...
# 9395                                  Type undetermined
# 7440                                  Type undetermined
# 4823                                     Interconnected
#
#                               status_of_fire_on_arrival          alarm_time  \
# 4743  Fire with smoke showing only - including vehic... 2014-03-27 08:02:56
# 3790  Flames showing from small area (one storey or ... 2014-08-09 16:22:10
# 9395  Fire with smoke showing only - including vehic... 2014-02-27 01:35:00
# 7440                  Fire with no evidence from street 2017-11-07 20:27:58
# 4823                 Fire extinguished prior to arrival 2014-04-03 17:05:03
#
#             arrival_time response_time
# 4743 2014-03-27 08:09:11         375.0
# 3790 2014-08-09 16:29:07         417.0
# 9395 2014-02-27 01:41:56         416.0
# 7440 2017-11-07 20:32:52         294.0
# 4823 2014-04-03 17:11:34         391.0
#
# [5 rows x 28 columns]

# %%
# What do the correlations look like

fire_num = fire.select_dtypes(include=['number', 'datetime'])
fire_cat = fire.select_dtypes(include=['object'])

# %%
fire_num.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8971 entries, 4743 to 7270
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   num_casualties         8971 non-null   int64
#  1   num_rescued            8971 non-null   int64
#  2   est_loss               8971 non-null   int64
#  3   est_displaced          8971 non-null   int64
#  4   incident_station_area  8971 non-null   int64
#  5   incident_ward          8942 non-null   float64
#  6   latitude               8971 non-null   float64
#  7   longitude              8971 non-null   float64
#  8   alarm_time             8971 non-null   datetime64[ns]
#  9   arrival_time           8971 non-null   datetime64[ns]
#  10  response_time          8971 non-null   float64
# dtypes: datetime64[ns](2), float64(4), int64(5)
# memory usage: 841.0 KB

# %%
fire_cat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8971 entries, 4743 to 7270
# Data columns (total 17 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   origin                                    8971 non-null   object
#  1   busi_impact                               8971 non-null   object
#  2   ext_agent_app_or_defer_time               8971 non-null   object
#  3   extent                                    8971 non-null   object
#  4   fire_alarm_impact_on_evac                 8971 non-null   object
#  5   fire_alarm_sys_op                         8971 non-null   object
#  6   fire_alarm_presence                       8971 non-null   object
#  7   fire_under_control_time                   8971 non-null   object
#  8   ignition_source                           8971 non-null   object
#  9   last_tfs_unit_clear_time                  8971 non-null   object
#  10  material_first_ignited                    8971 non-null   object
#  11  method_of_fire_control                    8971 non-null   object
#  12  possible_cause                            8971 non-null   object
#  13  property_use                              8971 non-null   object
#  14  smoke_alarm_at_fire_origin_alarm_failure  8971 non-null   object
#  15  smoke_alarm_at_fire_origin_alarm_type     8971 non-null   object
#  16  status_of_fire_on_arrival                 8971 non-null   object
# dtypes: object(17)
# memory usage: 1.2+ MB

# %%
corr_matrix = fire_num.corr()
corr_matrix['est_loss'].sort_values(ascending=False)
# Out:
# est_loss                 1.000000
# est_displaced            0.124613
# arrival_time             0.023541
# alarm_time               0.023541
# num_rescued              0.022099
# incident_station_area    0.018305
# num_casualties           0.013342
# response_time            0.004353
# latitude                -0.001024
# longitude               -0.012278
# incident_ward           -0.018928
# Name: est_loss, dtype: float64

# %%
# Add new features
fire_num['displaced_by_time'] = fire_num.est_displaced / (fire_num.response_time)
fire_num
# Out:
#       num_casualties  num_rescued  est_loss  est_displaced  \
# 4743               0            0     10000              0
# 3790               0            0     40000              0
# 9395               0            0     10000              0
# 7440               0            0      2000              0
# 4823               0            0       200              0
# ...              ...          ...       ...            ...
# 5734               0            0         0              0
# 5191               0            0       500              0
# 5390               0            0      3000              0
# 860                0            0     10000              4
# 7270               0            0       300              0
#
#       incident_station_area  incident_ward   latitude  longitude  \
# 4743                    333           30.0  43.645310 -79.352480
# 3790                    423           13.0  43.662240 -79.472250
# 9395                    321           26.0  43.697050 -79.370140
# 7440                    221           35.0  43.737820 -79.237790
# 4823                    125           26.0  43.710750 -79.331240
# ...                     ...            ...        ...        ...
# 5734                    443            4.0  43.682330 -79.526610
# 5191                    234           44.0  43.769200 -79.172160
# 5390                    311           22.0  43.679040 -79.398350
# 860                     142            7.0  43.751816 -79.516894
# 7270                    233           34.0  43.757830 -79.327150
#
#               alarm_time        arrival_time  response_time  displaced_by_time
# 4743 2014-03-27 08:02:56 2014-03-27 08:09:11          375.0           0.000000
# 3790 2014-08-09 16:22:10 2014-08-09 16:29:07          417.0           0.000000
# 9395 2014-02-27 01:35:00 2014-02-27 01:41:56          416.0           0.000000
# 7440 2017-11-07 20:27:58 2017-11-07 20:32:52          294.0           0.000000
# 4823 2014-04-03 17:05:03 2014-04-03 17:11:34          391.0           0.000000
# ...                  ...                 ...            ...                ...
# 5734 2012-12-03 11:43:26 2012-12-03 11:48:29          303.0           0.000000
# 5191 2015-11-17 23:20:37 2015-11-17 23:25:32          295.0           0.000000
# 5390 2017-03-11 14:20:32 2017-03-11 14:25:09          277.0           0.000000
# 860  2018-12-14 09:02:19 2018-12-14 09:04:35          136.0           0.029412
# 7270 2016-07-03 16:44:40 2016-07-03 16:50:04          324.0           0.000000
#
# [8971 rows x 12 columns]

# %%
corr_matrix = fire_num.corr()
corr_matrix['est_loss'].sort_values(ascending=False)
# Out:
# est_loss                 1.000000
# est_displaced            0.124613
# displaced_by_time        0.108217
# arrival_time             0.023541
# alarm_time               0.023541
# num_rescued              0.022099
# incident_station_area    0.018305
# num_casualties           0.013342
# response_time            0.004353
# latitude                -0.001024
# longitude               -0.012278
# incident_ward           -0.018928
# Name: est_loss, dtype: float64

# %% [markdown]
# ### 3b. Clean the data

# %%
fire_X = train_set.drop(columns=['est_loss'])
fire_y = train_set['est_loss']

# %%
fire_X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8971 entries, 4743 to 7270
# Data columns (total 26 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   origin                                    8971 non-null   object
#  1   busi_impact                               8971 non-null   object
#  2   num_casualties                            8971 non-null   int64
#  3   num_rescued                               8971 non-null   int64
#  4   est_displaced                             8971 non-null   int64
#  5   ext_agent_app_or_defer_time               8971 non-null   object
#  6   extent                                    8971 non-null   object
#  7   fire_alarm_impact_on_evac                 8971 non-null   object
#  8   fire_alarm_sys_op                         8971 non-null   object
#  9   fire_alarm_presence                       8971 non-null   object
#  10  fire_under_control_time                   8971 non-null   object
#  11  ignition_source                           8971 non-null   object
#  12  incident_station_area                     8971 non-null   int64
#  13  incident_ward                             8942 non-null   float64
#  14  last_tfs_unit_clear_time                  8971 non-null   object
#  15  latitude                                  8971 non-null   float64
#  16  longitude                                 8971 non-null   float64
#  17  material_first_ignited                    8971 non-null   object
#  18  method_of_fire_control                    8971 non-null   object
#  19  possible_cause                            8971 non-null   object
#  20  property_use                              8971 non-null   object
#  21  smoke_alarm_at_fire_origin_alarm_failure  8971 non-null   object
#  22  smoke_alarm_at_fire_origin_alarm_type     8971 non-null   object
#  23  status_of_fire_on_arrival                 8971 non-null   object
#  24  alarm_time                                8971 non-null   datetime64[ns]
#  25  arrival_time                              8971 non-null   datetime64[ns]
# dtypes: datetime64[ns](2), float64(3), int64(4), object(17)
# memory usage: 1.8+ MB

# %%
# We're going to fill the missing values of incident_ward with the median value

# %%
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy='median')

# %%
fire_X_num = fire_X.select_dtypes(include=['number'])

# %%
imputer.fit(fire_X_num)
# Out:
# SimpleImputer(strategy='median')

# %%
imputer.statistics_
# Out:
# array([  0.        ,   0.        ,   0.        , 314.        ,
#         19.        ,  43.69670845, -79.40365   ])

# %%
fire_X_num.median().values
# Out:
# array([  0.        ,   0.        ,   0.        , 314.        ,
#         19.        ,  43.69670845, -79.40365   ])

# %%
X = imputer.transform(fire_X_num)

# %%
fire_X_tr = pd.DataFrame(X, columns=fire_X_num.columns, index=fire_X_num.index)

# %%
fire_X_tr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8971 entries, 4743 to 7270
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   num_casualties         8971 non-null   float64
#  1   num_rescued            8971 non-null   float64
#  2   est_displaced          8971 non-null   float64
#  3   incident_station_area  8971 non-null   float64
#  4   incident_ward          8971 non-null   float64
#  5   latitude               8971 non-null   float64
#  6   longitude              8971 non-null   float64
# dtypes: float64(7)
# memory usage: 560.7 KB

# %%
# Create a custom function to add attributes

from sklearn.base import BaseEstimator, TransformerMixin

displaced, alarm_time, arrival_time = 2, 24, 25

class CustomAttr(BaseEstimator, TransformerMixin):
    def __init__(self, add_response_time = True, add_displaced_by_time = True):
        self.add_response_time = add_response_time
        self.add_displaced_by_time = add_displaced_by_time

    def fit(self, X, y = None):
        return self

    def transform(self, X, y = None):
        response_time = 0
        ala_time = pd.to_datetime(X[:, alarm_time])
        arr_time = pd.to_datetime(X[:, arrival_time])
        if self.add_response_time:
            response_time = (arr_time - ala_time).total_seconds()
            return np.c_[X, ala_time, arr_time, response_time]
        else:
            return np.c_[X, ala_time, arr_time]
            
        if self.add_displaced_by_time:
            disp_by_time = X[:, displaced] / (response_time)
            return np.c_[X, disp_by_time]
        else:
            return np.c_[X]

attr_adder = CustomAttr(add_response_time=True, add_displaced_by_time=True)
fire_extra_attribs = attr_adder.transform(fire_X.values)

# %%
fire_extra_attribs
# Out:
# array([['Trash, Rubbish Storage (inc garbage chute room, garbage/industri',
#         'No business interruption', 0, ..., 1395907376000000000,
#         1395907751000000000, 375.0],
#        ['Trash, rubbish area (outside)', 'No business interruption', 0,
#         ..., 1407601330000000000, 1407601747000000000, 417.0],
#        ['Concealed Ceiling Area', 'May resume operations within a week',
#         0, ..., 1393464900000000000, 1393465316000000000, 416.0],
#        ...,
#        ['Trash, rubbish area (outside)', 'No business interruption', 0,
#         ..., 1489242032000000000, 1489242309000000000, 277.0],
#        ['Cooking Area or Kitchen', 'Not applicable (not a business)', 0,
#         ..., 1544778139000000000, 1544778275000000000, 136.0],
#        ['Porch or Balcony', 'Not applicable (not a business)', 0, ...,
#         1467564280000000000, 1467564604000000000, 324.0]], dtype=object)

# %%
# Make a pipeline

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

num_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='median')),
    ('attribs_adder', CustomAttr()),
    ('std_scaler', StandardScaler()),
])

fire_num_tr = num_pipeline.fit_transform(fire_X_num)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[116], line 12
#       4 from sklearn.preprocessing import StandardScaler
#       6 num_pipeline = Pipeline([
#       7     ('imputer', SimpleImputer(strategy='median')),
#       8     ('attribs_adder', CustomAttr()),
#       9     ('std_scaler', StandardScaler()),
#      10 ])
# ---> 12 fire_num_tr = num_pipeline.fit_transform(fire_X_num)
#
# File P:\Projects\env\lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File P:\Projects\env\lib\site-packages\sklearn\pipeline.py:536, in Pipeline.fit_transform(self, X, y, **params)
#     493 """Fit the model and transform with the final estimator.
#     494
#     495 Fit all the transformers one after the other and sequentially transform
#    (...)
#     533     Transformed samples.
#     534 """
#     535 routed_params = self._check_method_params(method="fit_transform", props=params)
# --> 536 Xt = self._fit(X, y, routed_params)
#     538 last_step = self._final_estimator
#     539 with _print_elapsed_time("Pipeline", self._log_message(len(self.steps) - 1)):
#
# File P:\Projects\env\lib\site-packages\sklearn\pipeline.py:409, in Pipeline._fit(self, X, y, routed_params)
#     407     cloned_transformer = clone(transformer)
#     408 # Fit or load from cache the current transformer
# --> 409 X, fitted_transformer = fit_transform_one_cached(
#     410     cloned_transformer,
#     411     X,
#     412     y,
#     413     None,
#     414     message_clsname="Pipeline",
#     415     message=self._log_message(step_idx),
#     416     params=routed_params[name],
#     417 )
#     418 # Replace the transformer of the step with the fitted
#     419 # transformer. This is necessary when loading the transformer
#     420 # from the cache.
#     421 self.steps[step_idx] = (name, fitted_transformer)
#
# File P:\Projects\env\lib\site-packages\joblib\memory.py:312, in NotMemorizedFunc.__call__(self, *args, **kwargs)
#     311 def __call__(self, *args, **kwargs):
# --> 312     return self.func(*args, **kwargs)
#
# File P:\Projects\env\lib\site-packages\sklearn\pipeline.py:1329, in _fit_transform_one(transformer, X, y, weight, columns, message_clsname, message, params)
#    1327 with _print_elapsed_time(message_clsname, message):
#    1328     if hasattr(transformer, "fit_transform"):
# -> 1329         res = transformer.fit_transform(X, y, **params.get("fit_transform", {}))
#    1330     else:
#    1331         res = transformer.fit(X, y, **params.get("fit", {})).transform(
#    1332             X, **params.get("transform", {})
#    1333         )
#
# File P:\Projects\env\lib\site-packages\sklearn\utils\_set_output.py:313, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     311 @wraps(f)
#     312 def wrapped(self, X, *args, **kwargs):
# --> 313     data_to_wrap = f(self, X, *args, **kwargs)
#     314     if isinstance(data_to_wrap, tuple):
#     315         # only wrap the first output for cross decomposition
#     316         return_tuple = (
#     317             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     318             *data_to_wrap[1:],
#     319         )
#
# File P:\Projects\env\lib\site-packages\sklearn\base.py:1098, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#    1083         warnings.warn(
#    1084             (
#    1085                 f"This object ({self.__class__.__name__}) has a `transform`"
#    (...)
#    1093             UserWarning,
#    1094         )
#    1096 if y is None:
#    1097     # fit method of arity 1 (unsupervised transformation)
# -> 1098     return self.fit(X, **fit_params).transform(X)
#    1099 else:
#    1100     # fit method of arity 2 (supervised transformation)
#    1101     return self.fit(X, y, **fit_params).transform(X)
#
# File P:\Projects\env\lib\site-packages\sklearn\utils\_set_output.py:313, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     311 @wraps(f)
#     312 def wrapped(self, X, *args, **kwargs):
# --> 313     data_to_wrap = f(self, X, *args, **kwargs)
#     314     if isinstance(data_to_wrap, tuple):
#     315         # only wrap the first output for cross decomposition
#     316         return_tuple = (
#     317             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     318             *data_to_wrap[1:],
#     319         )
#
# Cell In[114], line 17, in CustomAttr.transform(self, X, y)
#      15 def transform(self, X, y = None):
#      16     response_time = 0
# ---> 17     ala_time = pd.to_datetime(X[:, alarm_time])
#      18     arr_time = pd.to_datetime(X[:, arrival_time])
#      19     if self.add_response_time:
#
# IndexError: index 24 is out of bounds for axis 1 with size 7

# %%
# Need to figure out a way to work with the object/datetime alarm_time and arrival_time to create a response_time column (float)
# At the moment, we can't pass datetime or object objects through the pipeline because of the imputer
